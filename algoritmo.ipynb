# %%
import pandas as pd

# %% [markdown]
# # Preprocesamiento

# %%
df = pd.read_csv('./Resources/data.csv')

# %%
df.head()
# Out:
#    id     estado  antiguedad       modalidad  \
# 0   1  Chihuahua         1.0   b.\tDistancia
# 1   2   Coahuila         0.0  a.\tPresencial
# 2   3   Coahuila        10.0   b.\tDistancia
# 3   4   Coahuila         8.0   b.\tDistancia
# 4   5   Coahuila         3.0  a.\tPresencial
#
#                                                value
# 0                              Selección de personal
# 1                Diseño de programas de capacitación
# 2           Construcción de la cartografía electoral
# 3  Operación de las comisiones de vigilancia del ...
# 4        Planeación de planes, programas y proyectos

# %% [markdown]
# Mapear las modalidades a variables numericas enteras.

# %%
mapping = {"a.\tPresencial": 0, "b.\tDistancia": 1, "c.\tMixta": 2}
df['modalidad'] = df['modalidad'].replace(mapping)
df.head()
# Out:
# C:\Users\cemh0\AppData\Local\Temp\ipykernel_1536\3187455827.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['modalidad'] = df['modalidad'].replace(mapping)
#    id     estado  antiguedad  modalidad  \
# 0   1  Chihuahua         1.0          1
# 1   2   Coahuila         0.0          0
# 2   3   Coahuila        10.0          1
# 3   4   Coahuila         8.0          1
# 4   5   Coahuila         3.0          0
#
#                                                value
# 0                              Selección de personal
# 1                Diseño de programas de capacitación
# 2           Construcción de la cartografía electoral
# 3  Operación de las comisiones de vigilancia del ...
# 4        Planeación de planes, programas y proyectos

# %% [markdown]
# Filtar los datos por modalidad a distancia y agrupar los cursos con su respectiva demanda.

# %%
demanda = df[df['modalidad'] == 1].drop(columns=['modalidad'])
demanda.rename(columns={'value': 'curso'}, inplace=True)
demanda.head(15)
# Out:
#     id            estado  antiguedad  \
# 0    1         Chihuahua         1.0
# 2    3          Coahuila        10.0
# 3    4          Coahuila         8.0
# 5    6         Chihuahua        30.0
# 7    8    Aguascalientes         8.0
# 8    9          Campeche         0.0
# 9   10            Puebla         1.0
# 10  11          Veracruz         1.5
# 12  13        Guanajuato         7.0
# 13  14          Veracruz        13.0
# 16  17  Ciudad de México        30.0
# 17  18  Ciudad de México        22.0
# 20  21            Oaxaca         1.6
# 21  22            México        10.0
# 24  25   San Luis Potosí        32.0
#
#                                                 curso
# 0                               Selección de personal
# 2            Construcción de la cartografía electoral
# 3   Operación de las comisiones de vigilancia del ...
# 5   Registro de actos de partidos y agrupaciones p...
# 7   Determinación de financiamiento público a part...
# 8   Distribución de documentación y material elect...
# 9                     Administración de base de datos
# 10  Operación de las comisiones de vigilancia del ...
# 12  Registro de actos de partidos y agrupaciones p...
# 13                    Administración de base de datos
# 16                          Procesamiento informático
# 17  Administración de tecnología de información y ...
# 20  Aplicación y gestión de recursos humanos, mate...
# 21               Diseño de materiales de capacitación
# 24           Construcción de la cartografía electoral

# %%
cursos = demanda['curso'].value_counts().reset_index()
cursos.columns = ['curso', 'counts']
cursos
# Out:
#                                                 curso  counts
# 0                       Atención de asuntos jurídicos     235
# 1   Aplicación y gestión de recursos humanos, mate...     190
# 2                               Selección de personal     170
# 3   Operación de las comisiones de vigilancia del ...     156
# 4                     Administración de base de datos     145
# 5   Actualización del padrón electoral y credencia...     132
# 6            Construcción de la cartografía electoral     129
# 7                     Depuración del padrón electoral     127
# 8               Fiscalización a los sujetos obligados     127
# 9                         Impartición de capacitación     121
# 10         Operación de módulos de atención ciudadana     113
# 11        Planeación de planes, programas y proyectos     113
# 12  Aplicación de metodología estadística y/o demo...     111
# 13       Seguimiento de planes, programas y proyectos      92
# 14                Diseño de programas de capacitación      92
# 15               Diseño de materiales de capacitación      90
# 16  Ubicación, equipamiento e instalación de casil...      85
# 17  Administración de tecnología de información y ...      84
# 18        Evaluación de planes, programas y proyectos      82
# 19                            Desarrollo de normativa      72
# 20                          Procesamiento informático      69
# 21  Determinación de financiamiento público a part...      66
# 22  Registro de actos de partidos y agrupaciones p...      62
# 23                Reincorporación al padrón electoral      61
# 24  Almacenamiento de documentación y material ele...      57
# 25  Distribución de documentación y material elect...      57
# 26                             Desarrollo de sistemas      56
# 27  Verificación de sesiones de los órganos descon...      52
# 28                  Verificación del padrón electoral      50
# 29  Diseño, mejora y producción de documentación e...      41
# 30  Diseño, mejora y producción de material electoral      41
# 31  Integración de mesas directivas de casilla o s...      40
# 32  Administración de los tiempos del estado en ra...      40
# 33               Administración de centros de cómputo      20
# 34  Ejecución de los procedimientos para administr...      20
# 35   Gestión de franquicias postales y/o telegráficas       4

# %% [markdown]
# Estructuras de datos para el algoritmo

# %%
# Ordenar dataframe O(nlogn)
cursos = cursos.sort_values(by=['counts'], ascending=False)
# Join de demanda con cursos (Investigar complejidad) Se agrego columna counts para ordenar
demanda = demanda.merge(cursos, on='curso', how='left')
# Ordenar dataframe O(nlogn)
demanda = demanda.sort_values(by=['counts', 'curso', 'antiguedad'], ascending=False)
# Investigar complejidad de drop
demanda.drop(columns=['counts'], inplace=True)
# Estructuras de datos
lista_demanda = demanda.to_dict(orient='records')
lista_cursos = cursos.to_dict(orient='records')

# %%
lista_demanda[:5]
# Out:
# [{'id': 1422,
#   'estado': 'Guanajuato',
#   'antiguedad': 36.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1719,
#   'estado': 'Ciudad de México',
#   'antiguedad': 32.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 385,
#   'estado': 'Jalisco',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 563,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 125,
#   'estado': 'Yucatán',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'}]

# %%
lista_cursos[:5]
# Out:
# [{'curso': 'Atención de asuntos jurídicos', 'counts': 235},
#  {'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros',
#   'counts': 190},
#  {'curso': 'Selección de personal', 'counts': 170},
#  {'curso': 'Operación de las comisiones de vigilancia del registro federal de electores',
#   'counts': 156},
#  {'curso': 'Administración de base de datos', 'counts': 145}]

# %% [markdown]
# # Algoritmo

# %% [markdown]
# **Problema.** Dado un número de $N$ grupos de tamano $n$ (la capacidad de asistentes a cada grupo); se busca asignar los lugares de los cursos a los trabajadores del INE, de manera que se priorice a los trabajadores con mayor antigüedad.
#
# 1. El algoritmo determinará si es posible colocar a los trabajadores con la configuración de cursos establecida. De no ser posible, se asignará un valor de $-1$ a las solicitudes que no pudieron tener un grupo asignado.
#
# 2. Devolverá un diccionario con los ids de los trabajadores, su estado, su antiguedad y el grupo del curso que les fue asignado. Se busca que se llenen los grupos y no queden lugares vacios.
#
# **Entradas.**
# - Una lista con diccionarios que contienen el nombre de un curso y el conteo de la demanda de dicho curso. Se asume que la lista esta ordenada con respecto al conteo de los cursos de mayor a menor.
# - Una lista con diccionarios que contienen los datos de un trabajador del INE y el curso que solicita tomar. Se asume que la lista esta ordenada con respecto al curso con mayor demanda y por mayor antiguedad.
# - $N>0$: Numero de grupos disponibles
# - $n>0$: Capacidad de asistentes en cada grupo del curso.
#
# **Salidas.**
# - Mensaje que indica si no posible la asignación de todos los trabajadores en los cursos.
# - Diccionario con la asignacion de trabajadores con los grupos de los cursos que les corresponde (o $-1$ si no pudo tener un grupo asignado).

# %%
def asignar_cursos(lista_cursos: list[dict], lista_demanda: list[dict], N: int, n: int) -> dict:
    # Inicializar diccionario de asignaciones
    asignaciones = {'id_trabajador': [], 'estado': [], 'antiguedad': [], 'curso': [], 'curso_id': []}

    # Inicializar variables
    grupo_id = 1
    residuos = []  # Para guardar las asignaciones residuales después de llenar los grupos

    # Primera ronda: Asignación principal por grupos del tamaño de n
    for curso in lista_cursos:
        curso_actual = curso['curso']
        demanda_restante = curso['counts']

        # Asignar trabajadores por grupos de tamaño n
        while demanda_restante >= n and N > 0:
            lugares_por_asignar = n
            if lugares_por_asignar <= demanda_restante:
                for _ in range(lugares_por_asignar):
                    if not lista_demanda:
                        break
                    row = lista_demanda.pop(0)
                    asignaciones['id_trabajador'].append(row['id'])
                    asignaciones['estado'].append(row['estado'])
                    asignaciones['antiguedad'].append(row['antiguedad'])
                    asignaciones['curso'].append(curso_actual)
                    asignaciones['curso_id'].append(grupo_id)

                # Restar la cantidad de trabajadores asignados del total de demanda
                demanda_restante -= lugares_por_asignar
                grupo_id += 1
                N -= 1  # Un grupo menos disponible

            # Si no se pueden llenar los grupos completos, guardar los residuos
            if demanda_restante < n:
                residuos.append({'curso': curso_actual, 'counts': demanda_restante})
                break

    # Segunda ronda: Asignación de residuos
    residuos = sorted(residuos, key=lambda x: x['counts'], reverse=True)

    for residuo in residuos:
        curso_actual = residuo['curso']
        demanda_restante = residuo['counts']

        while demanda_restante > 0 and N > 0:
            lugares_por_asignar = min(n, demanda_restante)  # Se asignan los lugares restantes según lo disponible
            for _ in range(lugares_por_asignar):
                if not lista_demanda:
                    break
                row = lista_demanda.pop(0)
                asignaciones['id_trabajador'].append(row['id'])
                asignaciones['estado'].append(row['estado'])
                asignaciones['antiguedad'].append(row['antiguedad'])
                asignaciones['curso'].append(curso_actual)
                asignaciones['curso_id'].append(grupo_id)

            # Restar la cantidad de trabajadores asignados del total de demanda
            demanda_restante -= lugares_por_asignar
            grupo_id += 1
            N -= 1  # Un grupo menos disponible

    # Asignar curso_id = -1 para los trabajadores que no se pudieron asignar
    for row in lista_demanda:
        asignaciones['id_trabajador'].append(row['id'])
        asignaciones['estado'].append(row['estado'])
        asignaciones['antiguedad'].append(row['antiguedad'])
        asignaciones['curso'].append(curso_actual)
        asignaciones['curso_id'].append(-1)

    # Imprimir advertencia si hay trabajadores sin asignar
    if lista_demanda:
        print('Advertencia: No fue posible asignar cursos a todos los trabajadores')
    return asignaciones

# %%
N = 160
n = 20

# %%
asignaciones = asignar_cursos(lista_cursos, lista_demanda, N, n)
# Out:
# Advertencia: No fue posible asignar cursos a todos los trabajadores

# %%
pd.DataFrame(asignaciones).head(30)
# Out:
#     id_trabajador            estado  antiguedad  \
# 0            1422        Guanajuato        36.0
# 1            1719  Ciudad de México        32.0
# 2             385           Jalisco        31.0
# 3             563            México        31.0
# 4             125           Yucatán        31.0
# 5             454         Michoacán        31.0
# 6            1039        Nuevo León        31.0
# 7            1794           Morelos        31.0
# 8             754  Ciudad de México        31.0
# 9             764        Nuevo León        31.0
# 10           1844        Guanajuato        31.0
# 11            596            México        30.0
# 12            747            México        30.0
# 13            850            México        30.0
# 14            990         Querétaro        30.0
# 15           1612           Chiapas        30.0
# 16           1722           Tabasco        30.0
# 17           1732        Nuevo León        30.0
# 18             17  Ciudad de México        30.0
# 19            843  Ciudad de México        30.0
# 20            946           Chiapas        30.0
# 21           2097           Sinaloa        30.0
# 22           1885          Guerrero        29.0
# 23            560  Ciudad de México        29.0
# 24           1005          Veracruz        29.0
# 25           1428    Aguascalientes        29.0
# 26           1593            Puebla        29.0
# 27           1986         Michoacán        29.0
# 28           2166   San Luis Potosí        29.0
# 29           1829   San Luis Potosí        29.0
#
#                             curso  curso_id
# 0   Atención de asuntos jurídicos         1
# 1   Atención de asuntos jurídicos         1
# 2   Atención de asuntos jurídicos         1
# 3   Atención de asuntos jurídicos         1
# 4   Atención de asuntos jurídicos         1
# 5   Atención de asuntos jurídicos         1
# 6   Atención de asuntos jurídicos         1
# 7   Atención de asuntos jurídicos         1
# 8   Atención de asuntos jurídicos         1
# 9   Atención de asuntos jurídicos         1
# 10  Atención de asuntos jurídicos         1
# 11  Atención de asuntos jurídicos         1
# 12  Atención de asuntos jurídicos         1
# 13  Atención de asuntos jurídicos         1
# 14  Atención de asuntos jurídicos         1
# 15  Atención de asuntos jurídicos         1
# 16  Atención de asuntos jurídicos         1
# 17  Atención de asuntos jurídicos         1
# 18  Atención de asuntos jurídicos         1
# 19  Atención de asuntos jurídicos         1
# 20  Atención de asuntos jurídicos         2
# 21  Atención de asuntos jurídicos         2
# 22  Atención de asuntos jurídicos         2
# 23  Atención de asuntos jurídicos         2
# 24  Atención de asuntos jurídicos         2
# 25  Atención de asuntos jurídicos         2
# 26  Atención de asuntos jurídicos         2
# 27  Atención de asuntos jurídicos         2
# 28  Atención de asuntos jurídicos         2
# 29  Atención de asuntos jurídicos         2

# %%
pd.DataFrame(asignaciones).to_csv('asignaciones.csv', index=False)
